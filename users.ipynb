# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv("users.csv", sep=",")

df.head()
# Out:
#                                          userid  \
# 0  uGlAuK3VrvANhAQAiFOJm1nbrXmFTwtmNRNE1g9Yd6k=
# 1  +tDWZynsin9nF3PNWStld8JMl7zNLFQP9hnKsFkpngk=
# 2  NNPBUwRmLGV+945vErmcyGIc2rCjh+GBdLJWeccGpIo=
# 3  kdrlgclBJnrkyaVcGHEnDL9R3xIjEWYf8CzaOrpOOjc=
# 4  14sKta+ATygMbCyCTMAF6sGqsR+FfyuwR4HKPzE05K4=
#
#                               user_display_name  \
# 0  uGlAuK3VrvANhAQAiFOJm1nbrXmFTwtmNRNE1g9Yd6k=
# 1  +tDWZynsin9nF3PNWStld8JMl7zNLFQP9hnKsFkpngk=
# 2  NNPBUwRmLGV+945vErmcyGIc2rCjh+GBdLJWeccGpIo=
# 3  kdrlgclBJnrkyaVcGHEnDL9R3xIjEWYf8CzaOrpOOjc=
# 4  14sKta+ATygMbCyCTMAF6sGqsR+FfyuwR4HKPzE05K4=
#
#                                user_screen_name user_reported_location  \
# 0  uGlAuK3VrvANhAQAiFOJm1nbrXmFTwtmNRNE1g9Yd6k=                中华人民共和国
# 1  +tDWZynsin9nF3PNWStld8JMl7zNLFQP9hnKsFkpngk=                    NaN
# 2  NNPBUwRmLGV+945vErmcyGIc2rCjh+GBdLJWeccGpIo=                    NaN
# 3  kdrlgclBJnrkyaVcGHEnDL9R3xIjEWYf8CzaOrpOOjc=                    NaN
# 4  14sKta+ATygMbCyCTMAF6sGqsR+FfyuwR4HKPzE05K4=                    NaN
#
#   user_profile_description user_profile_url  follower_count  following_count  \
# 0                        🥳              NaN               1               15
# 1                      NaN              NaN              21               70
# 2                      NaN              NaN               0                9
# 3                      NaN              NaN               1               62
# 4                      NaN              NaN               4               45
#
#   account_creation_date account_language
# 0            2019-01-12            zh-cn
# 1            2017-09-27            zh-cn
# 2            2017-08-30            zh-cn
# 3            2017-08-30            zh-cn
# 4            2017-08-30            zh-cn

# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv("users.csv", sep=",")

df.reset_index()['account_language'].value_counts()
# Out:
# zh-cn    612
# en       231
# ru        36
# es        18
# zh-CN     15
# zh-tw     11
# ja         8
# en-gb      5
# fr         4
# Name: account_language, dtype: int64

# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt 

df = pd.read_csv("users.csv", sep=",")

df.reset_index()['account_language'].value_counts().plot.bar(xlabel="Account Language", ylabel="Number of Accounts", figsize=(12,5))
plt.show()

# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt 

df = pd.read_csv("users.csv", sep=",")

df.reset_index()['account_language'].value_counts().plot.pie(ylabel="Percentage of Accounts by Language", figsize=(12,12))
plt.show()

# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt 

df = pd.read_csv("users.csv", sep=",")

df.plot.scatter(x='follower_count', y='following_count', figsize=(15,10))
plt.show()

# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt 

df = pd.read_csv("users.csv", sep=",")
df['account_creation_date'] = pd.to_datetime(df['account_creation_date'], format='%Y-%m-%d')

dg = df.reset_index()['account_creation_date'].value_counts().groupby(pd.Grouper(freq='M')).sum()
#dg.head(15)
dg.plot.line(x='account_creation_date', xlabel="Account Creation Date", ylabel="Number of Accounts", figsize=(15,10))
plt.show()
