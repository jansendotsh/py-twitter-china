# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv("tweets.csv", sep=",")

df.head()
# Out:
#               tweetid     userid  ...   user_mentions poll_choices
# 0  235862198621184000  206027550  ...   ['382613598']          NaN
# 1  209026577105821696  206027550  ...              []          NaN
# 2  569636537530392576  206027550  ...              []          NaN
# 3  565259976412004353  206027550  ...  ['2987944552']          NaN
# 4  577228355591757824  206027550  ...              []          NaN
#
# [5 rows x 31 columns]

# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv("tweets.csv", sep=",")

df.reset_index()['tweet_language'].value_counts().head(20)
#reset_index()['account_language'].value_counts()
# Out:
# in     794250
# ar     591415
# en     543526
# pt     203941
# zh     169363
# und    136422
# es      80749
# tl      40452
# ko      13403
# ja      11340
# fr      10653
# et       9657
# id       9120
# nl       8033
# ht       6077
# sv       5634
# fi       3974
# tr       3807
# de       3200
# pl       2901
# Name: tweet_language, dtype: int64

# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv("tweets.csv", sep=",")

df.reset_index()['tweet_language'].value_counts().head(12).plot.bar(xlabel="Tweet Language", ylabel="Number of Tweets", figsize=(12,5))
plt.show()

# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt 

df = pd.read_csv("tweets.csv", sep=",")

df.reset_index()['tweet_language'].value_counts().head(10).plot.pie(figsize=(12,12))
plt.show()

# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt 

df = pd.read_csv("tweets.csv", sep=",")
df['tweet_time'] = pd.to_datetime(df['tweet_time'], format='%Y-%m-%d %H:%M')

dg = df.reset_index()['tweet_time'].value_counts().groupby(pd.Grouper(freq='M')).sum()
#dg.head(15)
dg.plot.line(x='tweet_time', xlabel="Tweet Date", ylabel="Number of Accounts", figsize=(15,10))
plt.show()

# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt 

df = pd.read_csv("tweets.csv", sep=",")
dg = df.reset_index()['userid'].value_counts(sort=True)
dg.head(20)
# Out:
# 267090518                                       651821
# 769790067183190016                              264619
# 206027550                                       219549
# 620912741                                       183534
# 718766229700227072                              175874
# 791015242448850945                              161874
# 761109495187513344                              157380
# 760761981854883840                              118887
# 80073873                                        103420
# 158077925                                        88687
# 188403017                                        71311
# 122368257                                        66546
# +lR0YpwVOLofarNh58bAYIXsdTj1hTHJebgrEB9TI3s=     59536
# 129995319                                        41729
# 2346026113                                       38106
# 141413774                                        36217
# 2384663480                                       29913
# ...

# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt 

df = pd.read_csv("tweets.csv", sep=",")
dg = df.reset_index()['userid'].value_counts(sort=True)
dg.head(50).plot.pie(xlabel='', ylabel='', labels=None,figsize=(12,12))
plt.show()
